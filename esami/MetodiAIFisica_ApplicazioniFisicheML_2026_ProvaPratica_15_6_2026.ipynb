# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanogiagu/corso_AI_2026/blob/main/esami/MetodiAIFisica_ApplicazioniFisicheML_2026_ProvaPratica_15_6_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prova Pratica - Metodi AI per la fisica e Applicazioni Fisiche al ML
# ### 15.6.2026 - AA 2025/26 - Docenti: S. Giagu e A. Ciardiello
#
# ---
#
# **Regole:**
#
# *   **tempo a disposizione:** 2.0h
#
# *   compilare con i vostri dati i campi della cella che segue e poi eseguire la cella verificando che i dati printati corrispondano.
# *   risolvere i quesiti/compiti indicati nella cella *Descrizione del compito*.
# *   una volta completato il compito scaricare il notebook in formato *.ipynb* e caricarlo **usando il google form**:
# [consegna notebook](https://docs.google.com/forms/d/e/1FAIpQLSchUwfUyy9Z0bXpEquJB1LmvHIce3KhG_QVXAsfE9UJGV1nNA/viewform?usp=dialog)<p>
#
#
# **NOTA:** una volta caricato e sottomesso il notebook non sono più possibili ulteriori modifiche.

# %%
#@ Dati Personali
import os

Nome = 'Stefano'  #@param {type: "string"}
Cognome = 'Giagu' #@param {type: "string"}
NumeroMatricola = 12345678 #@param {type: "number"}

if NumeroMatricola == 12345678:
  print('\033[1;31m Inserisci il numero di matricola corretto!!!!')
else:
  print('\033[1;31m Done')
# Out:
#  Inserisci il numero di matricola corretto!!!!

# %% [markdown]
# # Descrizione del compito:
#
#
# Progettare tre reti neurali di tipo MLP per le seguenti task:
#
# 1. predire la media aritmetica di quattro numeri interi ($ m = \frac{1}{4}(a+b+c+d)$), ciascuno nel range $a,b,c,d \in [0,999]$, testandone le prestazioni sia "in distribution", sia "OOD" (su numeri interi nel range $[1000,9999]$
#
# 2. predire il risultato della divisione tra due numeri interi $a/b$, ciascuno nel range $a,b\in [0,999]$, testandone le prestazioni sia "in distribution", sia "OOD" (su numeri interi nel range $[1000,9999]$
#
# 3. contare il numero esatto di ciascun tipo di carattere in una sequenza di input costituita da $1000$ caratteri random scelti tra i quattro caratteri $[A, B, C, D]$, testandone le prestazioni ia "in distribution", sia "OOD" (su sequenze di lunghezza #1000#, costituite dai caratteri $[A, B, C, D, E, F, G, H]$ (potete codificare i caratteri non osservati durante il training con uno $0$).
#
# * spiegare quanto osservato e cercare di dare una motivazione delle prestazioni dell'MLP per ognuna delle tre task.
#
# * risolvere il punto 2), insegnando alla rete neurale a predire $\ln(a/b) = \ln(a) - \ln(b)$, e poi da questo direttamente ottenere $a/b$. Funziona meglio o peggio (in distributione e OOD) del caso 2)? Dare una spiegazione del perché.
#
# * **opzionale:** provare a risolvere la task 3) con una rete di tipo CNN. Funziona meglio, uguale, o peggio della MLP? Spiegare quanto osservato.
#
#
# * commentare opportunamente i risultati ottenuti in ogni punto.

# %%
#codice ...
