# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanogiagu/corso_AI_2026/blob/main/esami/MetodiAI_Fis2026_ProvaPratica_23_4_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Metodi AI per la Fisica - Prova Pratica Esame
# ### 23.4.2026 - AA 2025/26 - Docente: S. Giagu
#
#
# > **Regole:**
#
# *   **tempo a disposizione:** 1h45'
#
# *   compilare con i vostri dati i campi della cella che segue e poi eseguire la cella verificando che i dati printati corrispondano
# *   risolvere i quesiti/compiti indicati nella cella *Descrizione del compito* usando questo notebook
# *   una volta completato il compito inviare il notebook al docente <stefano.giagu@uniroma1.it>

# %%
#@ Dati Personali
import os

Nome = 'Stefano'  #@param {type: "string"}
Cognome = 'Giagu' #@param {type: "string"}
NumeroMatricola = 12345678 #@param {type: "number"}


if NumeroMatricola == 12345678:
  print('\033[1;31m Inserisci il numero di matricola corretto!!!!')
else:
  print('Downloading datasets')
  # !rm -rf diffr_data.npz
  # !wget http://giagu.web.cern.ch/giagu/CERN/diffr_data.npz
  print('Done')
# Out:
#  Inserisci il numero di matricola corretto!!!!

# %% [markdown]
# # Descrizione del compito:
#
# ### Dataset:
#
# il dataset fornito è costituito da un file formato *.npz* (numpy compresso): *diffr_data.npz*
# *   contiene in formato numpy 2 array: *X*, e *Y* di shape (3000,200,5) e (3000,), rispettivamente.
#
# *X* contiene 3000 immagini di dimensione (200,5) in scala di grigio di spettri di interferenza da doppia fenditura (includono effetti di rumore e risoluzione sperimentale), ottenuti per diversi valori del rapporto $\frac{\delta}{\lambda}$ tra distanza tra le fedniture e lunghezza d'onda dell'onda sferica che investe le due fenditure.
#
# *Y* contiene i valori corrispondenti di $\frac{\delta}{\lambda}$
#
# **Compiti:**
#
# 0.   leggere in numpy i due array e analizzare le caratteristiche che si ritengono più significative del dataset, plottando 9 immagini scelte in modo random da *X* organizzate in matplotlib in una matrice di 3x3 immagini;
# 1.   addestrare una rete densa al task di predire il valore del target Y a partire da un input costitutio solo dalla prima riga verticale delle immagini (e.g. $X[:,:,0]$, quindi un input piatto di dimensione 200) e misurarne opprotunamente le prestazioni;
# 2.   addestrare un modello generativo di tipo VAE, in grado di generare immagini della stessa tipologia del campione, generare 5 immagini e valutare nel modo che si ritiene più opportuno le prestazioni del modello generativo;
#
# * commentare opportunamente i risultati ottenuti in ogni punto

# %%
# codice ...
