# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanogiagu/corso_AI_2026/blob/main/esami/MetodiAIFisica_ApplicazioniFisicheML_2026_ProvaPratica_1_7_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prova Pratica - Metodi AI per la fisica e Applicazioni Fisiche al ML
# ### 1.7.2026 - AA 2025/26 - Docenti: S. Giagu e A. Ciardiello
#
# ---
#
# **Regole:**
#
# *   **tempo a disposizione:** 2.0h
#
# *   compilare con i vostri dati i campi della cella che segue e poi eseguire la cella verificando che i dati printati corrispondano.
# *   risolvere i quesiti/compiti indicati nella cella *Descrizione del compito*.
# *   una volta completato il compito scaricare il notebook in formato *.ipynb* e caricarlo **usando il google form**:
# [consegna notebook](https://docs.google.com/forms/d/e/1FAIpQLSeeO2-vbg6VZQOApd1qvfT66UcvDSxQMOYo0X1OR1EI4dtE6Q/viewform?usp=publish-editor)<p>
#
#
# **NOTA:** una volta caricato e sottomesso il notebook non sono più possibili ulteriori modifiche.

# %%
#@ Dati Personali
import os

Nome = 'Stefano'  #@param {type: "string"}
Cognome = 'Giagu' #@param {type: "string"}
NumeroMatricola = 12345678 #@param {type: "number"}

if NumeroMatricola == 12345678:
  print('\033[1;31m Inserisci il numero di matricola corretto!!!!')
else:
  # !rm -rf function_images.npy targets.npy
  # !wget http://giagu.web.cern.ch/giagu/CERN/dataset_img2d_max/function_images.npy
  # !wget http://giagu.web.cern.ch/giagu/CERN/dataset_img2d_max/targets.npy
  print('\033[1;31m Done')
# Out:
#  Inserisci il numero di matricola corretto!!!!

# %% [markdown]
# # Descrizione del compito:
#
# Viene fornito un dataset che consiste in 10000 esempi di distribuzioni bidimensionali di funzioni $y=f(x_1,x_2)$, con $x_1,x_2 \in [-10.,10.]$. Le distribuzioni sono fornite come array numpy di shape $(10000,64,64)$, in cui ogni pixel contiene il valore $y$ della funzione calcolata nel centro del pixel.
#
# Le immagini sono contenute nel file numpy *function_images.npy*.
#
# Insieme alle immagini, il file nmpy *targets.npy* contiene per ogni immagine le coordinate $(x_1,x_2, y_{max})$ del massimo della funzione.
#
# Risolvere le seguenti task:
#
# 1. analizzare le distribuzioni delle coordinate e dei valori del massimo delle funzioni, e graficare 9 immagini in una matrice di 3$\times$3 immagini, sovrapponendo ad ogni immagine un simbolo che indichi la posizione del valore vero del massimo (ground truth).
#
# 2. allenare una rete neurale a predire le coordinate del massimo della funzione rappresentata da ciascuna immagine, misurando in modo opportuno le prestazioni del modello.
#
# 3. allenare una "supervised VAE" a predire una maschera che indichi la posizione del massimo. L'encoder della VAE comprime l'immagine di input in uno spazio latente $z$ (con struttura probabilistica), il decoder mappa $z$ in un output (maschera) della stessa dimensione dell'immagine in input, in cui tutti i pixel hanno valore zero, tranne quello che corrisponde al massimo che ha valore 1.
#
# 4. graficare 9 immagini, con sovrapposta la maschera predetta dal modello (in modo che l'immagine sottostante sia visibile) e un marker che indichi la posizione vera del massimo per quell'immagine.
#
# 5. valutare nel modo che si ritiene più opportuno le prestazioni della VAE, e confrontarle con quelle del modello sviluppato nel punto 2. Commentare i risultati ottenuti.
#
# * commentare come ritenuto più opportuno i le scelte e i risultati ottenuti in ogni punto.

# %%
# scrivi il tuo codice e testo da qui in poi ...
